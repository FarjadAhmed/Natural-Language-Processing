# %% [markdown]
# # Hearst Patterns

# %% [markdown]
# ### A remark on scope of operators
#
# I have seen several solutions using disjunction with the wrong scope. This is illustrated by the following example:

# %%
import re

s = 'We met John and Mary.'
re.findall(r'\w+ and|or \w+',s)
# Out:
# ['John and']

# %% [markdown]
# The pattern is equivalent to the following one. Obviously not what was intended:

# %%
re.findall(r'(\w+ and)|(or \w+)',s)
# Out:
# [('John and', '')]

# %% [markdown]
# What we would like to have is the following:

# %%
re.findall(r'(\w+) (and|or) (\w+)',s)
# Out:
# [('John', 'and', 'Mary')]

# %% [markdown]
# Lessons learned (hopefully):
#     1. Test your patterns to make sure that they do what you think they do
#     2. Use brackets to make clear what the scope of operators is!

# %% [markdown]
# Also note what happens, if we use a Kleene Closure:

# %%
re.findall(r'((\w+ )+)(and |or )(\w+)',s)
# Out:
# [('We met John ', 'John ', 'and ', 'Mary')]

# %% [markdown]
# ## Intended solution
#
# In the following we use a lot of brackets. For each pattern we also stor which bracket group corresponds to the CONCEPT and which ones to INSTANCEs. Later we use this information to extract these parts.

# %%
import glob 
import codecs
import re
from collections import Counter



hearst_pat = [
    (r'([\w\-]+) such as ([\w\-]+) ((and|or) ([\w\-]+))?',0,[1,4]),
    (r'([\w\-]+),? especially ([\w\-]+) ((and|or) ([\w\-]+))?',0,[1,4]),
    (r'([\w\-]+),? including ([\w\-]+) ((and|or) ([\w\-]+))?',0,[1,4]),
    (r'([\w\-]+),? and other ([\w\-]+)',1,[0]),
    (r'([\w\-]+),? or other ([\w\-]+)',1,[0])
] 

paircount = Counter()

filelist = glob.glob("infect/*.txt")
for f in filelist:
    file = codecs.open(f,'r','utf8')

    for line in file:
        line = line.strip()
        for pat,cp,ips in hearst_pat: 
            resultlist = re.findall(pat,line) 
            for result in resultlist:
                concept = result[cp]
                for ip in ips:
                    if ip < len(result):
                        instance = result[ip]
                        if instance:
                            paircount.update([(concept,instance)])
                             
paircount.most_common()
# Out:
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# 1 [0]
# 1 [0]
# 0 [1, 4]
# 0 [1, 4]
# 0 [1, 4]
# ...
#  (('aminoglycoside', 'tobramycin'), 1),
#  (('affected', 'lung'), 1),
#  (('rules', 'the'), 1),
#  (('symptoms', 'therapy'), 1),
#  (('more', 'with'), 1),
#  (('or', 'severe'), 1),
#  (('means', 'vaccine'), 1),
#  (('preservatives', 'glycerol'), 1),
#  (('preservatives', 'kept'), 1),
#  (('resolve', 'in'), 1),
#  (('flora', 'staph'), 1),
#  (('agents', 'Ciprofloxacin'), 1),
#  (('areas', '1989'), 1),
#  (('microbes', 'novel'), 1),
#  (('infectious', 'diseases'), 1),
#  (('bacteria', 'Klebsiella'), 1),
#  (('bacteria', 'Proteus'), 1),
#  (('symptoms', 'reduced'), 1),
#  (('symptoms', 'alteration'), 1),
#  (('indicators', 'length'), 1),
#  (('groups', 'women'), 1),
#  (('groups', 'drug'), 1),
#  (('parts', 'Kingdom'), 1),
#  (('various', 'syphilis'), 1),
#  (('people', 'those'), 1),
#  (('STDs', 'syphilis'), 1),
#  (('science', 'epidemiology'), 1),
#  (('science', 'medicine'), 1),
#  (('hosts', 'humans'), 1),
#  (('lifestyle', 'their'), 1),
#  (('property', 'spacecraft'), 1),
#  (('consequences', 'home'), 1),
#  (('diseases', 'the'), 1),
#  (('ailments', 'rheumatism'), 1),
#  (('ailments', 'psoriasis'), 1),
#  (('syndrome', 'parasites'), 1),
#  (('syndrome', 'fungus'), 1),
#  (('world', 'sub-Saharan'), 1),
#  (('foods', 'lactose'), 1),
#  (('important', 'in'), 1),
#  (('Drinks', 'high'), 1),
#  (('living', 'animals'), 1),
#  (('agents', 'pathogenic'), 1),
#  (('factors', 'contaminated'), 1),
#  (('silkworm', 'this'), 1),
#  (('diseases', 'viruses'), 1),
#  (('factors', 'hunger'), 1),
#  (('factors', 'poverty'), 1),
#  (('creatures', 'insects'), 1),
#  (('weapons', 'guns'), 1),
#  (('diseases', 'these'), 1),
#  (('are', 'damaged'), 1),
#  (('peens', 'half'), 1),
#  (('groups', 'forces'), 1),
#  (('fabrics', 'clothing'), 1),
#  (('groups', 'Roman'), 1),
#  (('travelers', 'crusaders'), 1),
#  (('symptoms', 'cough'), 1),
#  (('contextual', 'legal'), 1),
#  (('diseases', 'heart'), 1),
#  (('effects', 'this'), 1),
#  (('microorganisms', 'fungi'), 1),
#  (('health', 'hospital'), 1),
#  (('clinical', 'laboratory'), 1),
#  (('procedures', 'surgery'), 1),
#  (('severe', 'sepsis'), 1),
#  (('lung', 'pneumonia'), 1),
#  (('bacteria', 'methicillin-resistant'), 1),
#  (('methods', 'Non-flammable'), 1),
#  (('preventive', 'washing'), 1),
#  (('antimicrobial', 'antibiotics'), 1),
#  (('patient-care', 'invasive'), 1),
#  (('disease', 'prevalent'), 1),
#  (('pathogens', 'Staphylococcus'), 1),
#  (('organisms', 'Staphylococcus'), 1),
#  (('bacteria', 'Enterobacter'), 1),
#  (('pathogens', 'Streptococcus'), 1),
#  (('disease', 'neurologic'), 1),
#  (('agents', 'viroids'), 1),
#  (('Lyssaviruses', 'Rabies'), 1),
#  (('yeasts', 'Candida'), 1),
#  (('Ascomycota', 'yeasts'), 1),
#  (('superficial', 'skin'), 1),
#  (('Basidiomycota', 'the'), 1),
#  (('nematodes', 'parasitic'), 1),
#  (('advanced', 'omics'), 1),
#  (('contact', 'by'), 1),
#  (('procedures', 'injection'), 1),
#  (('procedures', 'transplantation'), 1),
#  (('epidemiological', 'community'), 1),
#  (('plates', 'these'), 1),
#  (('Bacteria', 'Mycobacterium'), 1),
#  (('dye', 'Giemsa'), 1),
#  (('is', 'useful'), 1),
#  (('prove', 'useful'), 1),
#  (('is', 'infective'), 1),
#  (('is', 'easily'), 1),
#  (('contact', 'airborne'), 1),
#  (('prevention', 'avoiding'), 1),
#  (('membranes', 'the'), 1),
#  (('interactions', 'individuals'), 1),
#  (('animals', 'insects'), 1),
#  (('cargo', 'Ships'), 1),
#  (('specialists', 'bacteriologists'), 1),
#  (('association', 'studies'), 1),
#  (('lifestyle', 'diet'), 1),
#  (('measures', 'hand'), 1),
#  (('precautions', 'hand'), 1),
#  (('surfaces', 'medical'), 1),
#  (('microorganisms', 'bacterial'), 1),
#  (('sterilants', 'glutaraldehydes'), 1),
#  (('sterilants', 'formaldehyde'), 1),
#  (('materials', 'Hepatitis'), 1),
#  (('protocol', 'a'), 1),
#  (('modifications', 'tabs'), 1),
#  (('bodily', 'saliva'), 1),
#  (('blood', 'HIV'), 1),
#  (('actions', 'isolation'), 1),
#  (('online', 'microbiology'), 1),
#  (('of', 'all'), 1),
#  (('materials', 'blood'), 1),
#  (('means', 'DNA'), 1),
#  (('viruses', 'hepatitis'), 1),
#  (('is', 'strong'), 1),
#  (('animals', 'leukemias'), 1),
#  (('animals', 'lymphomas'), 1),
#  (('body', 'the'), 1),
#  (('neurological', 'Japan'), 1),
#  (('throat', 'the'), 1),
#  (('pylori', 'if'), 1),
#  (('Africa', 'when'), 1),
#  (('source', 'hairbrush'), 1),
#  (('germicide', 'a'), 1),
#  (('management', 'prescribing'), 1),
#  (('forms', 'AIDS'), 1),
#  (('countries', 'in'), 1),
#  (('terms', 'the'), 1),
#  (('coinfections', 'those'), 1),
#  (('symptoms', 'B'), 1),
#  (('inflammatory', 'fever'), 1),
#  (('diagnostic', 'criteria'), 1),
#  (('vector', 'in'), 1),
#  (('penicillin-like', 'penicillin'), 1),
#  (('beta-lactam', 'methicillin'), 1),
#  (('devices', 'catheters'), 1),
#  (('devices', 'artificial'), 1),
#  (('responses', 'the'), 1),
#  (('cohort', 'a'), 1),
#  (('system', 'summarizing'), 1),
#  (('shared', 'facility'), 1),
#  (('articles', 'medical'), 1),
#  (('measures', 'personal'), 1),
#  (('shopping', 'medicines'), 1),
#  (('essentials', 'food'), 1),
#  (('transmission', 'proper'), 1),
#  (('necessities', 'food'), 1),
#  (('medical', 'hospitals'), 1),
#  (('circumstances', 'in'), 1),
#  (('diseases', 'influenza'), 1),
#  (('organisms', 'CDV'), 1),
#  (('organisms', 'CAV'), 1),
#  (('infections', 'canine'), 1),
#  (('routinely', 'during'), 1),
#  (('administration', 'parenteral'), 1),
#  (('administration', 'intranasal'), 1),
#  (('severe', 'atelectasis'), 1),
#  (('criteria', 'the'), 1),
#  (('postulates', 'viruses'), 1),
#  (('diseases', 'viral'), 1),
#  (('occurrences', 'these'), 1),
#  (('diseases', 'SARS'), 1),
#  (('rate', 'specific'), 1),
#  (('infection', 'lung'), 1),
#  (('medications', 'anti-inflammatory'), 1),
#  (('factors', 'total'), 1),
#  (('organisms', 'the'), 1),
#  (('residues', 'cysteine'), 1),
#  (('antigens', 'antigen'), 1),
#  (('drugs', 'ciclosporin'), 1),
#  (('drugs', 'azathioprine'), 1),
#  (('models', 'those'), 1),
#  (('air', 'chemical'), 1),
#  (('occupied', 'people'), 1),
#  (('ectoparasites', 'scabies'), 1),
#  (('neglected', 'trichomoniasis'), 1),
#  (('developed', 'States'), 1),
#  (('symptoms', 'abdominal'), 1),
#  (('measures', 'disability-adjusted'), 1),
#  (('diseases', 'Chagas'), 1),
#  (('Projects', 'these'), 1),
#  (('communicable', 'diseases'), 1),
#  (('programs', 'this'), 1),
#  (('administration', 'with'), 1),
#  (('diseases', 'NTDs'), 1),
#  (('prevalent', 'diseases'), 1),
#  (('is', 'true'), 1),
#  (('pathogens', 'intestinal'), 1),
#  (('tasks', 'carrying'), 1),
#  (('eradication', 'for'), 1),
#  (('packages', 'four'), 1),
#  (('packages', 'five'), 1),
#  (('private', 'companies'), 1),
#  (('partnerships', 'if'), 1),
#  (('infections', 'when'), 1),
#  (('products', 'hot'), 1),
#  (('infections', 'respiratory'), 1),
#  (('tests', 'determining'), 1),
#  (('sexually', 'infection'), 1),
#  (('blood', 'levels'), 1),
#  (('HIV', 'previous'), 1),
#  (('obstetrical', 'membranes'), 1),
#  (('be', 'beneficial'), 1),
#  (('human', 'skin'), 1),
#  (('internal', 'bone'), 1),
#  (('evidence-based', 'literature'), 1),
#  (('disease-causative', 'postures'), 1),
#  (('benefits', 'economic'), 1),
#  (('animals', 'the'), 1),
#  (('Authorities', 'regulatory'), 1),
#  (('fatalities', 'in'), 1),
#  (('diseases', 'those'), 1),
#  (('biohazards', 'animal'), 1),
#  (('workers', 'veterinary'), 1),
#  (('hazards', 'surfaces'), 1),
#  (('risks', 'workplace'), 1),
#  (('groups', 'health'), 1),
#  (('equipment', 'harnesses'), 1),
#  (('equipment', 'guardrails'), 1),
#  (('procedures', 'securing'), 1),
#  (('were', 'high'), 1),
#  (('chemicals', 'Pesticides'), 1),
#  (('problems', 'the'), 1),
#  (('health', 'when'), 1),
#  (('OSHA', 'for'), 1),
#  (('harmful', 'foundries'), 1),
#  (('subsidiary', 'Regulations'), 1),
#  (('stakeholders', 'customers'), 1),
#  (('different', 'ideas'), 1),
#  (('relevant', 'hazards'), 1),
#  (('projects', 'Healthy'), 1),
#  (('Programs', 'these'), 1),
#  (('used', 'in'), 1),
#  (('pathologies', 'impetigo'), 1),
#  (('pathologies', 'strep'), 1),
#  (('infections', 'tuberculosis'), 1),
#  (('infections', 'meningitis'), 1),
#  (('animals', 'those'), 1),
#  (('organisms', 'microscopic'), 1),
#  (('body', 'milk'), 1),
#  (('bacteria', 'Streptococcus'), 1),
#  (('bacteria', 'Pseudomonas'), 1),
#  (('humans', 'Candida'), 1),
#  (('bacteria', 'both'), 1),
#  (('issues', 'browning'), 1),
#  (('issues', 'shorter'), 1),
#  (('viruses', 'the'), 1),
#  (('parts', 'tonsils'), 1),
#  (('infections', 'cellulitis'), 1),
#  (('was', 'necessary'), 1),
#  (('air', 'smoke'), 1),
#  (('common', 'drug-resistant'), 1),
#  (('occasionally', 'hantaviruses'), 1),
#  (('occasionally', 'coronaviruses'), 1),
#  (('medical', 'drugs'), 1),
#  (('lungs', 'Toxoplasma'), 1),
#  (('bacteria', 'Mycobacterium'), 1),
#  (('viruses', 'measles'), 1),
#  (('Complications', 'pleural'), 1),
#  (('patterns', 'vary'), 1),
#  (('medications', 'amantadine'), 1),
#  (('medications', 'rimantadine'), 1),
#  (('β-lactam', 'cephazolin'), 1),
#  (('macrolide', 'azithromycin'), 1),
#  (('pneumonias', 'SARS'), 1),
#  (('factors', 'the'), 1),
#  (('considered', 'a'), 1),
#  (('measures', 'muzzling'), 1),
#  (('wild', 'dogs'), 1),
#  (('wildlife', 'the'), 1),
#  (('furious', 'when'), 1),
#  (('War', 'the'), 1),
#  (('them', 'Matron'), 1),
#  (('France', 'in'), 1),
#  (('elements', 'the'), 1),
#  (('elements', 'cultural'), 1),
#  (('Avenue', 'retaining'), 1),
#  (('Avenue', 'ornamental'), 1),
#  (('setting', 'adjacent'), 1),
#  (('setting', 'associated'), 1),
#  (('setting', 'sandstone'), 1),
#  (('Group', 'former'), 1),
#  (('setting', 'historic'), 1),
#  (('Coastline', 'coastal'), 1),
#  (('Cemetery', 'its'), 1),
#  (('Site', 'Critical'), 1),
#  (('site', 'sandstone'), 1),
#  (('elements', 'rock'), 1),
#  (('plans', 'retaining'), 1),
#  (('cemeteries', 'the'), 1),
#  (('evidence', 'sandstone'), 1),
#  (('time', 'separate'), 1),
#  (('period', 'the'), 1),
#  (('buildings', 'Heffron'), 1),
#  (('phase', 'the'), 1),
#  (('authorities', 'Landcom'), 1),
#  (('authorities', 'the'), 1),
#  (('hospital', 'Ward'), 1),
#  (('features', 'the'), 1),
#  (('personnel', 'Dr'), 1),
#  (('buildings', 'the'), 1),
#  (('features', 'Pine'), 1),
#  (('landscape', 'Little'), 1),
#  (('wards', 'Ward'), 1),
#  (('wards', 'the'), 1),
#  (('community', 'the'), 1),
#  (('relationships', 'within'), 1),
#  (('evidence', 'oral'), 1),
#  (('institutions', 'the'), 1),
#  (('unique', 'the'), 1),
#  (('microflora', 'pollens'), 1),
#  (('products', 'hand'), 1),
#  (('activity', 'motor'), 1),
#  (('activity', 'motor-based'), 1),
#  (('sites', 'the'), 1),
#  (('Health', 'the'), 1),
#  (('rights', 'in'), 1),
#  (('quarantined', 'post-traumatic'), 1),
#  (('vehicles', 'the'), 1),
#  (('natural', 'wood'), 1),
#  (('days', 'the'), 1),
#  (('places', 'Marseille'), 1),
#  (('highly', 'fever'), 1),
#  (('orders', 'a'), 1),
#  (('landmarks', 'the'), 1),
#  (('then', 'for'), 1),
#  (('voyage', '36'), 1),
#  (('major', 'Wuhan'), 1),
#  (('risk', 'those'), 1),
#  (('countries', 'Australia'), 1),
#  (('countries', 'Japan'), 1),
#  (('mammals', 'humans'), 1),
#  (('animals', 'human'), 1),
#  (('nonspecific', 'fever'), 1),
#  (('nonspecific', 'headache'), 1),
#  (('wild', 'weasels'), 1),
#  (('arboviruses', 'West'), 1),
#  (('stray', 'if'), 1),
#  (('bat', 'in'), 1),
#  (('pets', 'dogs'), 1),
#  (('irritations', 'ulcers'), 1),
#  (('irritations', 'inflammation'), 1),
#  (('strains', 'the'), 1),
#  (('Methods', 'gas'), 1),
#  (('environments', 'the'), 1),
#  (('intense', 'reactions'), 1),
#  (('infections', 'environmental'), 1),
#  (('substrata', 'excreta'), 1),
#  (('vectors', 'urban'), 1),
#  (('but', 'in'), 1),
#  (('mosquito', 'Haemogogus'), 1),
#  (('mosquito', 'Aedes'), 1),
#  (('mosquitoes', 'Haemagogus'), 1),
#  (('conditions', 'cancer'), 1),
#  (('conditions', 'diabetes'), 1),
#  (('people', 'the'), 1),
#  (('syndromes', 'hemophagocytic'), 1),
#  (('factors', 'nuclear'), 1),
#  (('Cytokines', 'tumor'), 1),
#  (('vessels', 'nitric'), 1),
#  (('processes', 'excessive'), 1),
#  (('evidence', 'pressure'), 1),
#  (('sites', 'respiratory'), 1),
#  (('organisms', 'Pseudomonas'), 1),
#  (('origin', 'acute'), 1),
#  (('others', 'those'), 1),
#  (('arrhythmia', 'torsades'), 1),
#  (('sepsis', 'people'), 1),
#  (('illness', 'cancer'), 1),
#  (('physicians', 'after'), 1),
#  (('individuals', 'the'), 1),
#  (('density', 'train'), 1),
#  (('are', 'vulnerable'), 1),
#  (('vectors', 'mosquitoes'), 1),
#  (('vectors', 'other'), 1),
#  (('used', 'the'), 1),
#  (('Empire', 'dumping'), 1),
#  (('social-distancing', 'gatherings'), 1),
#  (('insects', 'mosquitoes'), 1),
#  (('mitigation', 'face'), 1),
#  (('conditions', 'cystic'), 1),
#  (('all', 'essential'), 1),
#  (('policies', 'stay-at-home'), 1),
#  (('and', 'complete'), 1),
#  (('contagious', 'leprosy'), 1),
#  (('measures', 'closing'), 1),
#  (('places', 'theatres'), 1),
#  (('social', 'closures'), 1),
#  (('forms', 'closure'), 1),
#  (('measures', 'finding'), 1),
#  (('measures', 'isolating'), 1),
#  (('public', 'theaters'), 1),
#  (('measures', 'social-distancing'), 1),
#  (('measures', 'self-isolation'), 1),
#  (('celebrities', 'Taylor'), 1),
#  (('conditions', 'anxiety'), 1),
#  (('panic', 'for'), 1),
#  (('but', 'for'), 1),
#  (('services', 'special'), 1),
#  (('techniques', 'polymerase'), 1),
#  (('diseases', 'AIDS'), 1),
#  (('diseases', 'genital'), 1),
#  (('signs', 'behavior'), 1),
#  (('factors', 'a'), 1),
#  (('events', 'SARS-CoV-2'), 1),
#  (('events', 'SARS'), 1),
#  (('locals', '19'), 1),
#  (('people', 'Tablighi'), 1),
#  (('COVID-19', 'three'), 1),
#  (('contacts', 'housekeepers'), 1),
#  (('three', 'He'), 1),
#  (('cities', '30'), 1),
#  (('opioid', 'heroin'), 1),
#  (('General', 'the'), 1),
#  (('extremities', 'the'), 1),
#  (('subspecies', 'yaws'), 1),
#  (('testing', 'email'), 1),
#  (('testing', 'text'), 1),
#  (('wounds', 'cancres'), 1),
#  (('sex', 'sexual'), 1),
#  (('figures', 'Franz'), 1),
#  (('literature', 'John'), 1),
#  (('sexually', 'syphilis'), 1),
#  (('resuscitation', 'the'), 1),
#  (('blood', 'HBV'), 1),
#  (('modalities', 'alcohol-based'), 1),
#  (('pathogens', 'those'), 1),
#  (('patients', 'patient'), 1),
#  (('intestinal', 'noroviruses'), 1),
#  (('discharges', 'incontinence'), 1),
#  (('rooms', 'walls'), 1),
#  (('tests', 'those'), 1),
#  (('months', 'in'), 1),
#  (('diseases', 'varicella'), 1),
#  (('diseases', 'tuberculosis'), 1),
#  (('mood', 'depression'), 1),
#  (('Protozoa', 'Giardia'), 1),
#  (('Protozoans', 'Giardia'), 1),
#  (('hot', 'coffee'), 1),
#  (('uncooked', 'lettuce'), 1),
#  (('establishments', 'vendors'), 1),
#  (('clear', 'water'), 1),
#  (('drugs', 'loperamide'), 1),
#  (('drugs', 'diphenoxylate'), 1),
#  (('outdoor', 'campers'), 1),
#  (('Insects', 'mosquitoes'), 1),
#  (('Insects', 'flies'), 1),
#  (('tourism', 'travel'), 1),
#  (('Toxins', 'Tropical'), 1),
#  (('communicable', 'tropical'), 1),
#  (('colors', 'bright'), 1),
#  (('phagocytes', 'macrophages'), 1),
#  (('phagocytes', 'neutrophils'), 1),
#  (('is', 'good'), 1),
#  (('profiles', 'the'), 1),
#  (('allergic', 'cells'), 1),
#  (('cells', 'natural'), 1),
#  (('diseases', 'Type'), 1),
#  (('CD4', 'macrophages'), 1),
#  (('CD4', 'dendritic'), 1),
#  (('viruses', 'HIV'), 1),
#  (('groups', 'IgG'), 1),
#  (('groups', 'IgA'), 1),
#  (('infections', 'in'), 1),
#  (('disease', 'diphtheria'), 1),
#  (('disease', 'measles'), 1),
#  (('tract', 'the'), 1),
#  (('Mucolytics', 'acetylcysteine'), 1),
#  (('Mucolytics', 'carbocystine'), 1),
#  (('antibiotics', 'nitrofurantoin'), 1),
#  (('antibiotics', 'trimethoprim'), 1),
#  (('bacteria', 'Enterococcus'), 1),
#  (('others', 'the'), 1),
#  (('UTIs', 'acute'), 1),
#  (('fluoroquinolones', 'a'), 1),
#  (('Complications', 'ureteral'), 1),
#  (('fluid', 'biological'), 1),
#  (('fluid', 'environmental'), 1),
#  (('microorganisms', 'archaea'), 1),
#  (('viruses', 'influenza'), 1),
#  (('viruses', 'those'), 1),
#  (('noxious', 'poison'), 1),
#  (('diseases', 'typhoid'), 1),
#  (('diseases', 'cholera'), 1),
#  (('structures', 'capsids'), 1),
#  (('bacteria', 'rickettsia'), 1),
#  (('bacteria', 'chlamydia'), 1),
#  (('membranes', 'a'), 1),
#  (('structures', 'protein'), 1),
#  (('advantages', 'resistance'), 1),
#  (('of', 'plant'), 1),
#  (('diseases', 'multiple'), 1),
#  (('vectors', 'when'), 1),
#  (('factors', 'host'), 1),
#  (('families', 'both'), 1),
#  (('species', 'humans'), 1),
#  (('mechanisms', 'cells'), 1),
#  (('Cells', 'the'), 1),
#  (('anti-viral', 'lamivudine'), 1),
#  (('Diseases', 'foot-and-mouth'), 1),
#  (('species', 'tomatoes'), 1),
#  (('species', 'peppers'), 1),
#  (('phytoplankton', 'harmful'), 1),
#  (('proteins', 'vaccine'), 1),
#  (('factors', 'epidermal'), 1),
#  (('risk', 'in'), 1),
#  (('diseases', 'Ebola'), 1),
#  (('pathogens', 'emergent'), 1),
#  (('media', 'air'), 1),
#  (('products', 'pork'), 1),
#  (('roundworm', 'species'), 1),
#  (('settings', 'zoos'), 1),
#  (('animals', 'rats'), 1),
#  (('animals', 'birds'), 1),
#  (('diseases', 'African'), 1)]

# %% [markdown]
# We now get many results like $(('animals', 'cats'), 1)$ meaning that cats are animals.

# %% [markdown]
# ## Extended Solution
#
# Results would be better if we could restrict to nouns and proper names. Let us try to do so!

# %%
import nltk

def tag_text(txt):
    sentences = ['/'.join(token) for s in nltk.sent_tokenize(txt) for token in nltk.pos_tag(nltk.word_tokenize(s))]
    return ' '.join(sentences)

# %%
text = 'The word quarantine comes from quarantena or quarantaine, meaning "forty days", used in the Venetian language in the 14th and 15th centuries and also in France. The word is designated in the period during which all ships were required to be isolated before passengers and crew could go ashore during the Black Death plague. The quarantena followed the trentino, or "thirty-day isolation" period, first imposed in 1347 in the Republic of Ragusa, Dalmatia (modern Dubrovnik in Croatia).Merriam-Webster gives various meanings to the noun form, including "a period of 40 days", several relating to ships, "a state of enforced isolation", and as "a restriction on the movement of people and goods which is intended to prevent the spread of disease or pests". The word is also used as a verb. Quarantine is distinct from medical isolation, in which those confirmed to be infected with a communicable disease are isolated from the healthy population. Quarantine may be used interchangeably with cordon sanitaire, and although the terms are related, cordon sanitaire refers to the restriction of movement of people into or out of a defined geographic area, such as a community, in order to prevent an infection from spreading.'

# %%
tag_text(text)
# Out:
# "The/DT word/NN quarantine/NN comes/VBZ from/IN quarantena/NN or/CC quarantaine/NN ,/, meaning/VBG ``/`` forty/JJ days/NNS ''/'' ,/, used/VBD in/IN the/DT Venetian/JJ language/NN in/IN the/DT 14th/CD and/CC 15th/CD centuries/NNS and/CC also/RB in/IN France/NNP ./. The/DT word/NN is/VBZ designated/VBN in/IN the/DT period/NN during/IN which/WDT all/DT ships/NNS were/VBD required/VBN to/TO be/VB isolated/VBN before/IN passengers/NNS and/CC crew/NN could/MD go/VB ashore/RB during/IN the/DT Black/NNP Death/NNP plague/NN ./. The/DT quarantena/NN followed/VBD the/DT trentino/NN ,/, or/CC ``/`` thirty-day/JJ isolation/NN ''/'' period/NN ,/, first/RB imposed/VBN in/IN 1347/CD in/IN the/DT Republic/NNP of/IN Ragusa/NNP ,/, Dalmatia/NNP (/( modern/JJ Dubrovnik/NNP in/IN Croatia/NNP )/) .Merriam-Webster/NN gives/VBZ various/JJ meanings/NNS to/TO the/DT noun/JJ form/NN ,/, including/VBG ``/`` a/DT period/NN of/IN 40/CD days/NNS ''/'' ,/, several/JJ relating/VBG to/TO ships/VB ,/, ``/`` a/DT state/NN of/IN enforced/JJ isolation/NN ''/'' ,/, and/CC as/IN ``/`` a/DT restriction/NN on/IN the/DT movement/NN of/IN people/NNS and/CC goods/NNS which/WDT is/VBZ intended/VBN to/TO prevent/VB the/DT spread/NN of/IN disease/NN or/CC pests/NNS ''/'' ./. The/DT word/NN is/VBZ also/RB used/VBN as/IN a/DT verb/NN ./. Quarantine/NN is/VBZ distinct/JJ from/IN medical/JJ isolation/NN ,/, in/IN which/WDT those/DT confirmed/VBN to/TO be/VB infected/VBN with/IN a/DT communicable/JJ disease/NN are/VBP isolated/VBN from/IN the/DT healthy/JJ population/NN ./. Quarantine/NN may/MD be/VB used/VBN interchangeably/RB with/IN cordon/NN sanitaire/NN ,/, and/CC although/IN the/DT terms/NNS are/VBP related/VBN ,/, cordon/JJ sanitaire/NN refers/NNS to/TO the/DT restriction/NN of/IN movement/NN of/IN people/NNS into/IN or/CC out/IN of/IN a/DT defined/JJ geographic/JJ area/NN ,/, such/JJ as/IN a/DT community/NN ,/, in/IN order/NN to/TO prevent/VB an/DT infection/NN from/IN spreading/VBG ./."

# %%
print(tag_text("animals, including dogs and cats."))
print(tag_text("animals, especially Dogs and cats."))
print(tag_text("dogs and other animals."))
# Out:
# animals/NNS ,/, including/VBG dogs/NNS and/CC cats/NNS ./.
# animals/NNS ,/, especially/RB Dogs/NNP and/CC cats/NNS ./.
# dogs/NNS and/CC other/JJ animals/NNS ./.

# %% [markdown]
# Now we have to adjust the regular expressions.

# %%
hearst_pat = [
    (r'(\S+/NN[SP]?) such/JJ as/IN (\S+/NN[SP]?) ((and|or)/CC (\S+/NN[SP]?))?',0,[1,4]),
    (r'(\S+/NN[SP]?)( ,/,)? especially/\w+ (\S+/NN[SP]?) ((and|or)/CC (\S+/NN[SP]?))?',0,[2,5]),
    (r'(\S+/NN[SP]?)( ,/,)? including/\w+ (\S+/NN[SP]?) ((and|or)/CC (\S+/NN[SP]?))?',0,[2,5]),
    (r'(\S+/NN[SP]?)( ,/,)? (and|or)/CC other/\w+ (\S+/NN[SP]?)',3,[0])
]

paircount = Counter()

filelist = glob.glob("infect/*.txt")
for f in filelist:
    file = codecs.open(f,'r','utf8')

    for line in file:
        line = tag_text(line)
        for pat,cp,ips in hearst_pat:
            resultlist = re.findall(pat,line) 
            for result in resultlist:
                concept = result[cp].split('/')[0]
                for ip in ips:
                    if ip < len(result):
                        instance = result[ip].split('/')[0]
                        if instance:
                            paircount.update([(concept,instance)])
                             
paircount.most_common()
# Out:
# []

# %% [markdown]
# We could make many extensions and include cases with more complex noun phrases. Let us try slightly more complex phrases. In order to keep the expressions readable, we will abbreviate the NPs and expand them later.
#
# Furthermore, we compile the regex to speed up the process a little bit.

# %%
NP = r'\\S+/NN[SP]?( \\S+/NN[SP]?)*'

hearst_pat = [
    (r'(NP) such/JJ as/IN( \w+/DT)? (NP) ((and|or)/CC( \w+/DT)? (NP))?',0,[3,8]),
    (r'(NP)( ,/,)? especially/\w+( \w+/DT)? (NP) ((and|or)/CC( \w+/DT)? (NP))?',0,[4,9]),
    (r'(NP)( ,/,)? including/\w+( \w+/DT)? (NP) ((and|or)/CC( \w+/DT)? (NP))?',0,[4,9]),
    (r'(NP)( ,/,)? (and|or)/CC other/\w+ (NP)',4,[0])
]

hearst_pat = [(re.compile(re.sub('NP',NP,p)),c,i) for p,c,i in hearst_pat]

# %%
paircount = Counter()

filelist = glob.glob("infect/*.txt")
for f in filelist:
    file = codecs.open(f,'r','utf8')

    for line in file:
        line = tag_text(line)
        for pat,cp,ips in hearst_pat:
            resultlist = pat.findall(line) #use the compiled pattern
            for result in resultlist:
                concept = result[cp].split('/')[0]
                for ip in ips:
                    if ip < len(result):
                        instance = re.sub(r'/[A-Z]+','',result[ip])
                        if instance:
                            paircount.update([(concept,instance)])
                             
paircount.most_common()
# Out:
# []

# %%
len(paircount)
# Out:
# 0

# %%
sum(paircount.values())
# Out:
# 0
